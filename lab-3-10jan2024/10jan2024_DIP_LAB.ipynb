# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot  as plt

# %%
print(cv2.__version__)
# Out:
# 4.9.0

# %%
img = cv2.imread("ironman.jpg",cv2.IMREAD_COLOR)
img = cv2.resize(img, (600, 300))  
cv2.imshow("& I am IronMan",img)  
cv2.waitKey(0)  
cv2.destroyAllWindows()

# %%
color=cv2.cvtColor(img,cv2.COLOR_BGR2RGB) 
plt.imshow(color) 
plt.title("& I am IronMan")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 color=cv2.cvtColor(img,cv2.COLOR_BGR2RGB)
#       2 plt.imshow(color)
#       3 plt.title("& I am IronMan")
#
# NameError: name 'cv2' is not defined

# %%
img2 = cv2.imread("scarletwitch.jpg",cv2.IMREAD_COLOR)
img2 = cv2.resize(img2, (400, 700))  
cv2.imshow("A great mommy",img2)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
color2=cv2.cvtColor(img2,cv2.COLOR_BGR2RGB)
plt.imshow(color2)
plt.title("A great Mommy")
# Out:
# Text(0.5, 1.0, 'A great Mommy')

# %%
img.shape
# Out:
# (300, 600, 3)

# %%
path=r"C:\Users\hp\IIT-DIP-LAB\10jan2024\ironman.jpg"

# %%
img3=cv2.imread(path,cv2.IMREAD_GRAYSCALE)
plt.imshow(img3)

# %%
import os

# %%
image_path=r"C:\Users\hp\IIT-DIP-LAB\10jan2024\scarletwitch.jpg"

# %%
directory=r'C:\Users\hp\IIT-DIP-LAB\10jan2024\Test'

# %%
img4=cv2.imread(image_path)

# %%
os.chdir(directory)

# %%
print("Before saving image")
print(os.listdir(directory))
# Out:
# Before saving image
# ['.ipynb_checkpoints', 'Ju logo.png', 'mommy.jpg']

# %%
filename="mommy.jpg"

# %%
cv2.imwrite(filename,img4)
# Out:
# True

# %%
print("After saving image:")
print(os.listdir(directory))
# Out:
# After saving image:
# ['.ipynb_checkpoints', 'Ju logo.png', 'mommy.jpg']
