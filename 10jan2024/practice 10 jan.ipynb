# %%
import numpy as np
import pandas as pd
import cv2
import matplotlib.pyplot as plt
print(cv2.__version__)
# Out:
# C:\Users\hp\AppData\Local\Temp\ipykernel_3256\3782694842.py:2: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
# 4.9.0

# %%
img = cv2.imread('ironman.jpg', cv2.IMREAD_COLOR)
img = cv2.resize(img, (600, 600))
cv2.imshow('here is the image', img)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %%
color=cv2.cvtColor(img, cv2.COLOR_BGR2RGB) 
plt.imshow(color)
plt.title('acccha ekta title')
# Out:
# Text(0.5, 1.0, 'acccha ekta title')

# %%
img2 = cv2.imread('scarletwitch.jpg', cv2.IMREAD_COLOR)
# color2 = cv2.cvtColor(img2, cv2.COLOR_BGR2RGB)
plt.imshow(img2)

# %%
path = r"C:\Users\hp\IIT-DIP-LAB\10jan2024\scarletwitch.jpg"

# %%
dir = r'C:\Users\hp\IIT-DIP-LAB\10jan2024\Test'

# %%
img3 = cv2.imread(path)

# %%
import os
os.chdir(dir)

# %%
print(os.listdir(dir))
# Out:
# ['.ipynb_checkpoints', 'Ju logo.png', 'mommy.jpg']

# %%
filename = 'hoowowow.jpg'

# %%
cv2.imwrite(filename, img3)
# Out:
# True

# %%
print(os.listdir(dir))
# Out:
# ['.ipynb_checkpoints', 'hoowowow.jpg', 'Ju logo.png', 'mommy.jpg']
